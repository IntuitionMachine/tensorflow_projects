# %% [raw]
# ---
# title: Neural Style Transfer
# authors:
# - Somshubra Majumdar
# tags:
# - image
# - style
# created_at: 2016-06-29
# updated_at: 2016-06-30
# tldr: Neural Style Transfer from the paper 'A Neural Algorithm of Artistic Style'.
# thumbnail: images/output_23_1.png
# ---

# %%
# !git clone https://github.com/titu1994/Neural-Style-Transfer.git
# Out:
# Cloning into 'Neural-Style-Transfer'...
# remote: Enumerating objects: 1332, done.
# remote: Total 1332 (delta 0), reused 0 (delta 0), pack-reused 1332
# Receiving objects: 100% (1332/1332), 66.56 MiB | 14.51 MiB/s, done.
# Resolving deltas: 100% (781/781), done.
# Checking connectivity... done.

# %%
dir_path = "Neural-Style-Transfer"

# %% [markdown]
# # Network Type
#
# Choose the network type below :
#
# - "Network" for the original style transfer
# - "INetwork" for the improved style transfer (default)

# %%
NETWORK = 'INetwork' + '.py'

# %%
# List all the arguments that can be supplied to Network.py
# !python3 {dir_path}/{NETWORK} -h
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/distributions/distribution.py:265: ReparameterizationType.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/distributions/bernoulli.py:169: RegisterKL.__init__ (from tensorflow.python.ops.distributions.kullback_leibler) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# usage: INetwork.py [-h] [--style_masks STYLE_MASKS [STYLE_MASKS ...]]
#                    [--content_mask CONTENT_MASK] [--color_mask COLOR_MASK]
#                    [--image_size IMG_SIZE] [--content_weight CONTENT_WEIGHT]
#                    [--style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]]
#                    [--style_scale STYLE_SCALE]
#                    [--total_variation_weight TV_WEIGHT] [--num_iter NUM_ITER]
#                    [--model MODEL] [--content_loss_type CONTENT_LOSS_TYPE]
#                    [--rescale_image RESCALE_IMAGE]
#                    [--rescale_method RESCALE_METHOD]
#                    [--maintain_aspect_ratio MAINTAIN_ASPECT_RATIO]
#                    [--content_layer CONTENT_LAYER] [--init_image INIT_IMAGE]
#                    [--pool_type POOL] [--preserve_color COLOR]
#                    [--min_improvement MIN_IMPROVEMENT]
#                    base ref [ref ...] res_prefix
#
# Neural style transfer with Keras.
#
# positional arguments:
#   base                  Path to the image to transform.
#   ref                   Path to the style reference image.
#   res_prefix            Prefix for the saved results.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --style_masks STYLE_MASKS [STYLE_MASKS ...]
#                         Masks for style images
#   --content_mask CONTENT_MASK
#                         Masks for the content image
#   --color_mask COLOR_MASK
#                         Mask for color preservation
#   --image_size IMG_SIZE
#                         Minimum image size
#   --content_weight CONTENT_WEIGHT
#                         Weight of content
#   --style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]
#                         Weight of style, can be multiple for multiple styles
#   --style_scale STYLE_SCALE
#                         Scale the weighing of the style
#   --total_variation_weight TV_WEIGHT
#                         Total Variation weight
#   --num_iter NUM_ITER   Number of iterations
#   --model MODEL         Choices are 'vgg16' and 'vgg19'
#   --content_loss_type CONTENT_LOSS_TYPE
#                         Can be one of 0, 1 or 2. Readme contains the required
#                         information of each mode.
#   --rescale_image RESCALE_IMAGE
#                         Rescale image after execution to original dimentions
#   --rescale_method RESCALE_METHOD
#                         Rescale image algorithm
#   --maintain_aspect_ratio MAINTAIN_ASPECT_RATIO
#                         Maintain aspect ratio of loaded images
#   --content_layer CONTENT_LAYER
#                         Content layer used for content loss.
#   --init_image INIT_IMAGE
#                         Initial image used to generate the final image.
#                         Options are 'content', 'noise', or 'gray'
#   --pool_type POOL      Pooling type. Can be "ave" for average pooling or
#                         "max" for max pooling
#   --preserve_color COLOR
#                         Preserve original color in image
#   --min_improvement MIN_IMPROVEMENT
#                         Defines minimum improvement required to continue
#                         script

# %% [markdown]
# # Network Parameters
#
# Here, we will setup all of the parameters for the `Network.py` script.

# %%
# Image size
IMAGE_SIZE = 500

# Loss Weights
CONTENT_WEIGHT = 0.025
STYLE_WEIGHT = 1.0
STYLE_SCALE = 1.0
TOTAL_VARIATION_WEIGHT = 8.5e-5
CONTENT_LOSS_TYPE = 0

# Training arguments
NUM_ITERATIONS = 10
MODEL = 'vgg19'
RESCALE_IMAGE = 'false'
MAINTAIN_ASPECT_RATIO = 'false'  # Set to false if OOM occurs

# Transfer Arguments
CONTENT_LAYER = 'conv' + '5_2'  # only change the number 5_2 to something in a similar format
INITIALIZATION_IMAGE = 'content'
POOLING_TYPE = 'max'

# Extra arguments
PRESERVE_COLOR = 'false'
MIN_IMPROVEMENT = 0.0

# %% [markdown]
# # Content Image
#
# Run the below cell to upload the Content Image. Make sure to select **just 1 image**

# %%
#from google.colab import files

#content_img = files.upload()

# %%
# import os

# CONTENT_IMAGE_FN = list(content_img)[0]
# CONTENT_IMAGE_FN_temp = CONTENT_IMAGE_FN.strip().replace(" ", "_")

# if CONTENT_IMAGE_FN != CONTENT_IMAGE_FN_temp:
#   os.rename(CONTENT_IMAGE_FN, CONTENT_IMAGE_FN_temp)
#   CONTENT_IMAGE_FN = CONTENT_IMAGE_FN_temp
  
# print("Content image filename :", CONTENT_IMAGE_FN)

# %%
import os

#Set relative directory for content images
content_image_dir = os.path.join(dir_path,'images','inputs','content')

#List of available images
content_list = os.listdir(content_image_dir)

# %%
content_list
# Out:
# ['Japanese-cherry-widescreen-wallpaper-Picture-1366x768.jpg',
#  'Dipping-Sun.jpg',
#  'winter-wolf.jpg',
#  'Kinkaku-ji.jpg',
#  'golden_gate.jpg',
#  'sagano_bamboo_forest.jpg',
#  'Aurea-Luna.jpg',
#  'blue-moon-lake.jpg',
#  'tubingen.jpg',
#  'ancient_city.jpg',
#  'Sunlit Mountains.jpg',
#  'Dawn Sky.jpg']

# %%
#Select image file from content directory
content_img = 'blue-moon-lake.jpg'
content_img
# Out:
# 'blue-moon-lake.jpg'

# %%
#Ensures all spaces are removed as required by the script

CONTENT_IMAGE_FN_temp = content_img.strip().replace(" ", "_")

if content_img != CONTENT_IMAGE_FN_temp:
  os.rename(os.path.join(content_image_dir, content_img), os.path.join(content_image_dir,CONTENT_IMAGE_FN_temp))
  CONTENT_IMAGE_FN = os.path.join(content_image_dir,CONTENT_IMAGE_FN_temp)
else:
    CONTENT_IMAGE_FN = os.path.join(content_image_dir,content_img)
        
  
print("Content image filename :", CONTENT_IMAGE_FN)
# Out:
# Content image filename : Neural-Style-Transfer/images/inputs/content/blue-moon-lake.jpg

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
img = plt.imread(CONTENT_IMAGE_FN)
plt.axis('off')
plt.title('Content image')
plt.imshow(img)

# %% [markdown]
# # Style Image
#
# Run the below cell to upload the Style Image. Make sure to select **just 1 image**

# %%
# style_img = files.upload()

# %%
# STYLE_IMAGE_FN = list(style_img)[0]
# STYLE_IMAGE_FN_temp = STYLE_IMAGE_FN.strip().replace(" ", "_")

# if STYLE_IMAGE_FN != STYLE_IMAGE_FN_temp:
#   os.rename(STYLE_IMAGE_FN, STYLE_IMAGE_FN_temp)
#   STYLE_IMAGE_FN = STYLE_IMAGE_FN_temp
  
# print("Style image filename :", STYLE_IMAGE_FN)

# %%
#Set relative directory for content images
style_image_dir = os.path.join(dir_path,'images','inputs','style')

#List of available images
style_list = os.listdir(style_image_dir)

# %%
style_list
# Out:
# ['misty-mood-leonid-afremov.jpg',
#  'candy-style.jpg',
#  'patterned_leaves.jpg',
#  'blue_swirls.jpg',
#  'the_scream.jpg',
#  'starry_night.jpg',
#  'metals',
#  'frida_kahlo.jpg',
#  'water-lilies-1919-2.jpg',
#  'wave_kanagawa.jpg',
#  'woman-with-hat-matisse.jpg',
#  'japanese_flower_sakai_hoitsu.jpg',
#  'Blue Strokes.jpg',
#  'starry_night_crop.png',
#  'picasso_selfport1907.jpg',
#  'bamboo_forest.jpg',
#  'red-canna.jpg',
#  'escher_sphere.jpg',
#  'seated-nude.jpg',
#  'shipwreck.jpg',
#  'japanese_painting.jpg']

# %%
#Select image file from content directory
style_img = 'starry_night.jpg'
style_img
# Out:
# 'starry_night.jpg'

# %%
#Ensures all spaces are removed as required by the script

STYLE_IMAGE_FN_temp = style_img.strip().replace(" ", "_")

if style_img != STYLE_IMAGE_FN_temp:
  os.rename(os.path.join(style_image_dir, style_img), os.path.join(style_image_dir,STYLE_IMAGE_FN_temp))
  STYLE_IMAGE_FN = os.path.join(style_image_dir,STYLE_IMAGE_FN_temp)
else:
    STYLE_IMAGE_FN = os.path.join(style_image_dir,style_img)
        
  
print("Style image filename :", STYLE_IMAGE_FN)
# Out:
# Style image filename : Neural-Style-Transfer/images/inputs/style/starry_night.jpg

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(STYLE_IMAGE_FN)
plt.axis('off')
plt.title('Style image')
plt.imshow(img)

# %% [markdown]
# # Generate Image
#
# Run the below cells to generate the image

# %%
import os

RESULT_DIR = "generated/"
RESULT_PREFIX = RESULT_DIR + "gen"
FINAL_IMAGE_PATH = RESULT_PREFIX + "_at_iteration_%d.png" % (NUM_ITERATIONS)

if not os.path.exists(RESULT_DIR):
  os.makedirs(RESULT_DIR)

# %%
#changed from python to python3
# !python3 {dir_path}/{NETWORK} {CONTENT_IMAGE_FN} {STYLE_IMAGE_FN} {RESULT_PREFIX} \
  --image_size {IMAGE_SIZE} --content_weight {CONTENT_WEIGHT} --style_weight \
  {STYLE_WEIGHT} --style_scale {STYLE_SCALE} --total_variation_weight \
  {TOTAL_VARIATION_WEIGHT} --content_loss_type {CONTENT_LOSS_TYPE} --num_iter \
  {NUM_ITERATIONS} --model {MODEL} --rescale_image {RESCALE_IMAGE} \
  --maintain_aspect_ratio {MAINTAIN_ASPECT_RATIO} --content_layer {CONTENT_LAYER} \
  --init_image {INITIALIZATION_IMAGE} --pool_type {POOLING_TYPE} --preserve_color \
  {PRESERVE_COLOR} --min_improvement {MIN_IMPROVEMENT}
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/distributions/distribution.py:265: ReparameterizationType.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/distributions/bernoulli.py:169: RegisterKL.__init__ (from tensorflow.python.ops.distributions.kullback_leibler) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# 2019-05-04 09:47:40.512427: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2019-05-04 09:47:40.512907: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1530] Found device 0 with properties:
# name: Vega 10 XT [Radeon RX Vega 64]
# AMDGPU ISA: gfx900
# memoryClockRate (GHz) 1.63
# pciBusID 0000:03:00.0
# Total memory: 7.98GiB
# Free memory: 7.73GiB
# 2019-05-04 09:47:40.512934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1641] Adding visible gpu devices: 0
# 2019-05-04 09:47:40.513088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1051] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-05-04 09:47:40.513098: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1057]      0
# 2019-05-04 09:47:40.513107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1070] 0:   N
# 2019-05-04 09:47:40.513145: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1189] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7524 MB memory) -> physical GPU (device: 0, name: Vega 10 XT [Radeon RX Vega 64], pci bus id: 0000:03:00.0)
# Model loaded.
# Starting iteration 1 of 10
# 2019-05-04 09:47:50.216484: I tensorflow/core/kernels/conv_grad_input_ops.cc:1023] running auto-tune for Backward-Data
# 2019-05-04 09:47:50.266360: I tensorflow/core/kernels/conv_grad_input_ops.cc:1023] running auto-tune for Backward-Data
# 2019-05-04 09:47:50.290963: I tensorflow/core/kernels/conv_grad_input_ops.cc:1023] running auto-tune for Backward-Data
# 2019-05-04 09:47:50.315143: I tensorflow/core/kernels/conv_grad_input_ops.cc:1023] running auto-tune for Backward-Data
# 2019-05-04 09:47:50.341052: I tensorflow/core/kernels/conv_grad_input_ops.cc:1023] running auto-tune for Backward-Data
# 2019-05-04 09:47:50.365924: I tensorflow/core/kernels/conv_grad_input_ops.cc:1023] running auto-tune for Backward-Data
# 2019-05-04 09:47:50.392285: I tensorflow/core/kernels/conv_grad_input_ops.cc:1023] running auto-tune for Backward-Data
# 2019-05-04 09:47:50.417590: I tensorflow/core/kernels/conv_grad_input_ops.cc:1023] running auto-tune for Backward-Data
# 2019-05-04 09:47:50.445493: I tensorflow/core/kernels/conv_grad_input_ops.cc:1023] running auto-tune for Backward-Data
# Current loss value: 231435100.0  Improvement : 0.000 %
# Rescaling Image to (500, 800)
# Image saved as generated/gen_at_iteration_1.png
# Iteration 1 completed in 20s
# Starting iteration 2 of 10
# Current loss value: 89968270.0  Improvement : 61.126 %
# Rescaling Image to (500, 800)
# Image saved as generated/gen_at_iteration_2.png
# Iteration 2 completed in 19s
# Starting iteration 3 of 10
# Current loss value: 60709428.0  Improvement : 32.521 %
# Rescaling Image to (500, 800)
# Image saved as generated/gen_at_iteration_3.png
# Iteration 3 completed in 19s
# Starting iteration 4 of 10
# Current loss value: 48765772.0  Improvement : 19.673 %
# Rescaling Image to (500, 800)
# Image saved as generated/gen_at_iteration_4.png
# Iteration 4 completed in 19s
# Starting iteration 5 of 10
# Current loss value: 41613320.0  Improvement : 14.667 %
# Rescaling Image to (500, 800)
# Image saved as generated/gen_at_iteration_5.png
# Iteration 5 completed in 19s
# Starting iteration 6 of 10
# Current loss value: 37694056.0  Improvement : 9.418 %
# Rescaling Image to (500, 800)
# Image saved as generated/gen_at_iteration_6.png
# Iteration 6 completed in 19s
# Starting iteration 7 of 10
# Current loss value: 34577200.0  Improvement : 8.269 %
# Rescaling Image to (500, 800)
# Image saved as generated/gen_at_iteration_7.png
# Iteration 7 completed in 19s
# Starting iteration 8 of 10
# Current loss value: 32486390.0  Improvement : 6.047 %
# Rescaling Image to (500, 800)
# Image saved as generated/gen_at_iteration_8.png
# Iteration 8 completed in 19s
# Starting iteration 9 of 10
# Current loss value: 30887736.0  Improvement : 4.921 %
# Rescaling Image to (500, 800)
# Image saved as generated/gen_at_iteration_9.png
# Iteration 9 completed in 19s
# Starting iteration 10 of 10
# Current loss value: 29684198.0  Improvement : 3.896 %
# Rescaling Image to (500, 800)
# Image saved as generated/gen_at_iteration_10.png
# Iteration 10 completed in 19s

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(FINAL_IMAGE_PATH)
plt.axis('off')
plt.title('Generated image')
plt.imshow(img)

# %% [markdown]
# # (Optional) Color Transfer
#
# If you wish for color transfer between the content image and the generated image, then run the next cell, else skip to "Download Generated Image" section

# %%
COLOR_TRANSFER = 'color_transfer.py'
COLOR_FINAL_IMAGE_PATH = FINAL_IMAGE_PATH[:-4] + '_%s_color.png'

# Optional - Use Histogram matching (0 for no, 1 for yes)
HISTOGRAM_MATCH = 0

if HISTOGRAM_MATCH == 0:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('original')
else:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('histogram')
  
#Changed python to python3
# !python3 {dir_path}/{COLOR_TRANSFER} {CONTENT_IMAGE_FN} {FINAL_IMAGE_PATH} --hist_match {HISTOGRAM_MATCH}
# Out:
# Image saved at path : generated/gen_at_iteration_10_original_color.png

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(COLOR_FINAL_IMAGE_PATH)
plt.axis('off')
plt.title('Color Transferred Generated image')
plt.imshow(img)

# %% [markdown]
# # Download Color Transfered Image
#
# Run the following cell to download the color transferred result

# %%
# download the color transfered image
# files.download(COLOR_FINAL_IMAGE_PATH)

# %% [markdown]
# # Download Generated Image
#
# Run the following cell to download the final result

# %%
#files.download(FINAL_IMAGE_PATH)
