# %% [markdown]
# To start, let's download the dataset from:
#
# 'vgg_conv.npy' binary (115.5 MB) which contains calibrated convolution filters from vgg19 network.
# [md5sum: bf8a930fec201a0a2ade13d3f7274d0e] originally from: https://app.box.com/v/vgg19-conv-npy
#
# copied to a GDrive for download convinience
# https://drive.google.com/open?id=1EPl3S6R-b4uamWMfXKwH0N7QWSMzDnSg

# %%
#https://github.com/ndrplz/google-drive-downloader

# !pip3 install googledrivedownloader

# Install a lower version of Numpy to fix the bug for custom tensorflow build:
# https://stackoverflow.com/questions/55890813/how-to-fix-object-arrays-cannot-be-loaded-when-allow-pickle-false-for-imdb-loa
# !pip3 install numpy==1.16.1

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd

gdd.download_file_from_google_drive(file_id='1EPl3S6R-b4uamWMfXKwH0N7QWSMzDnSg',
                                    dest_path='./vgg_conv.npy',
                                    unzip=False)

# %%
# !python3 basic_styletrans.py --subject media/wave_small.jpg --style media/kngwa_small.jpg --output media/wave_kngwa.jpg --vggnet vgg_conv.npy
# Out:
# 2019-06-04 07:28:11.099850: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-04 07:28:11.175292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-06-04 07:28:11.175626: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# name: GeForce GTX 1080 Ti major: 6 minor: 1 memoryClockRate(GHz): 1.683
# pciBusID: 0000:01:00.0
# totalMemory: 10.91GiB freeMemory: 10.44GiB
# 2019-06-04 07:28:11.175638: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1484] Adding visible gpu devices: 0
# 2019-06-04 07:28:11.332991: I tensorflow/core/common_runtime/gpu/gpu_device.cc:965] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-04 07:28:11.333016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971]      0
# 2019-06-04 07:28:11.333021: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] 0:   N
# 2019-06-04 07:28:11.333150: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1097] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10057 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2019-06-04 07:28:15.357121: I tensorflow/core/kernels/cuda_solvers.cc:159] Creating CudaSolver handles for stream 0x56225a40d2e0
# loss: 251,173,952.00
# ALL DONE
# post clip | time: 153.3 final loss: 2,722,316.00
# synthesized image saved: media/wave_kngwa.jpg

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

#Show the image that was processed:
img = Image.open('media/wave_small.jpg')
imgplot = plt.imshow(img)

# %%
#Show the style:

img = Image.open('media/kngwa_small.jpg')
imgplot = plt.imshow(img)

# %%
#Show the output:

img = Image.open('media/wave_kngwa.jpg')
imgplot = plt.imshow(img)
